# %%
import json
from datetime import datetime
from cryptography.fernet import Fernet
import pandas as pd
import plotly.express as px

# Load the encryption key
with open("secret.key", "rb") as key_file:
    fernet_key = key_file.read()
fernet = Fernet(fernet_key)

# Load and decrypt student data
with open("data.encrypted", "rb") as f:
    encrypted_data = f.read()
decrypted_data = fernet.decrypt(encrypted_data)
student_data = json.loads(decrypted_data.decode('utf-8'))

print("Data loaded and decrypted successfully.")
# Out:
# Data loaded and decrypted successfully.

# %%
birthdays = []

for student in student_data:
    try:
        tgl_lahir = datetime.strptime(student['tgllahir'], "%d-%m-%Y")

        # Ambil nama belakang
        full_name = student["nama"].strip()
        last_name = full_name.split()[-1].title()

        birthdays.append({
            "Nama": last_name,
            "Bulan": tgl_lahir.strftime("%B"),
            "Tanggal": tgl_lahir.day
        })

    except (ValueError, TypeError, KeyError):
        continue

df = pd.DataFrame(birthdays)

df_pivot = df.pivot_table(
    index='Tanggal',
    columns='Bulan',
    values='Nama',
    aggfunc=lambda x: ', '.join(x)
).fillna('')

month_order = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]

df_pivot = df_pivot.reindex(columns=month_order)

df_pivot
# Out:
# Bulan    January February          March       April        May  \
# Tanggal
# 1
# 2                                Firdaus
# 3                   Amory
# 4        Alzuhry  Siregar
# 5                                                         Faruq
# 6                                                     Mahardika
# 7                                               Abdi
# 8
# 9                 Nugraha           Jati
# 10
# 11
# 12                             Rafiuddin                   Aini
# 15
# 16                                                    Silitonga
# 17
# 18                                              Afif
# 19                              Erlangga
# 20
# 21       Fradana
# 22                                              H.Q.
# 24         Insan
# 25       Mulyadi                           Fachrizky
# 26        Thariq
# 28                         Syafi'Izzudin    Hermawan
# 29                                        Rafsanjani  Heriyanto
# 30
#
# Bulan                     June       July   August   September    October  \
# Tanggal
# 1                                                                   Fahmi
# 2                                          Hidayah
# 3
# 4                                                                Maghrobi
# 5                      Saputra
# 6                      Rosyadi
# 7                   Fiorentino
# 8                                                     Chasanah
# 9                                  Wibowo
# 10
# 11
# 12
# 15                        Sari                             Adi
# 16
# 17       Alfaiqoh, Anshoruddin               Falah
# 18                              Setyatama
# 19
# 20                   Kurniawan              Alkais
# 21               Safitri, Afaf
# 22                                                  Atho'Illah
# 24
# 25
# 26                                                     Makarim  Virgianto
# 28
# 29                                                      Bukian
# 30                  Yudhistira
#
# Bulan     November December
# Tanggal
# 1
# 2
# 3        Wicaksana
# 4
# 5                     Putra
# 6
# 7
# 8
# 9
# 10          Arrafi
# 11                  Mu'Izha
# 12                     Huda
# 15                  Widjaya
# 16         Saputro  Nararya
# 17
# 18
# 19
# 20         Sanjaya
# 21
# 22
# 24
# 25
# 26
# 28
# 29
# 30

# %%
fig = px.treemap(
    df,
    path=["Bulan", "Tanggal", "Nama"],
    title="Distribusi Ulang Tahun Mahasiswa"
)

fig.show()
